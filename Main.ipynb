# %%
# Import statements
import pandas as pd
#import pyspark
#from pyspark import SparkContext

# %%
# Load symbols_valid_meta to get reference Stocks and ETFs with full name. 

nomenclature = pd.read_csv('data/symbols_valid_meta.csv')
nomenclature
# Out:
#      Nasdaq Traded Symbol                                      Security Name  \
# 0                Y      A            Agilent Technologies, Inc. Common Stock
# 1                Y     AA                    Alcoa Corporation Common Stock
# 2                Y   AAAU                       Perth Mint Physical Gold ETF
# 3                Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4                Y   AADR                AdvisorShares Dorsey Wright ADR ETF
# ...            ...    ...                                                ...
# 8044             Y    ZUO                   Zuora, Inc. Class A Common Stock
# 8045             Y    ZVO                          Zovio Inc. - Common Stock
# 8046             Y   ZYME                       Zymeworks Inc. Common Shares
# 8047             Y   ZYNE       Zynerba Pharmaceuticals, Inc. - Common Stock
# 8048             Y   ZYXI                         Zynex, Inc. - Common Stock
#
# ...

# %%
nomenclature.loc[nomenclature['Symbol'] == 'UTX.V']
# Out:
#      Nasdaq Traded Symbol                                      Security Name  \
# 7457             Y  UTX.V  United Technologies Corporation Common Stock E...
#
#      Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 7457                N                   N           100.0          N
#
#      Financial Status CQS Symbol NASDAQ Symbol NextShares
# 7457              NaN       UTXw          UTX#          N

# %%
# We need a way to automatically deal with the special char treatment of pd.read_csv
# When we read the csv into panda df, special characters get treated differently (e.g. '-' tunrns into '$')
# dealing with it hard coded right now (3 instances)

nomenclature.at[162,'Symbol'] = 'AGM-A'
nomenclature.at[1068,'Symbol'] = 'CARR#'
nomenclature.at[7457,'Symbol'] = 'UTX#'

# %%
# Give me a count for the files we have so we can loop through them, and some fries on the side

import pathlib

stock_count, etf_count = 0, 0
for path in pathlib.Path("data/stocks").iterdir():
    if path.is_file():
        stock_count += 1

print("Stock file count: ", stock_count)

for path in pathlib.Path("data/etfs").iterdir():
    if path.is_file():
        etf_count += 1

print("Etf file count: ", etf_count)
# Out:
# Stock file count:  5884
# Etf file count:  2165

# %%
# Load the files into one big list of dataframes and normalize dates according to pandas
# yahoo finance package dealt with pandas date normalization  

stock_df_list = []
etf_df_list = []

for i in range(len(nomenclature)):
    if nomenclature['ETF'][i] == 'Y':
        etf_df_list.append(pd.read_csv('data/etfs/' + nomenclature['Symbol'][i] +'.csv'))
    else:
        stock_df_list.append(pd.read_csv('data/stocks/' + nomenclature['Symbol'][i] +'.csv'))

# %%
# Seperate stocks into 3 types and drop stocks with history < 3 years, 2018 and younger
# Type I: Longer than 25 years
# Type 2: 25y and younger
# Type 3: After 2009 

stocks_relevant = [s for s in stock_df_list if s['Date'][0] < '2018-01-01']
stocks_type_3 = [s for s in stocks_relevant if s['Date'][0] > '2009-12-31']
stocks_type_2 = [s for s in stocks_relevant if s['Date'][0] > '1994-12-31']
stocks_type_1 = [s for s in stocks_relevant if s['Date'][0] < '1994-12-31']

# %%
# Separate the stocks into the years 2000 - 20005

# %%
# Separate the efts into the years 2000 - 2005

# %%
# Do analysis on the stocks for the subset of the years and complete clustering on them

# %%
# Do analysis on the etfs for the subset of the years and complete clustering on them
